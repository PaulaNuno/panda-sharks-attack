# %%
# importamos las bibliotecas necesarias para el análisis
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', 500)
df = pd.read_csv('input/attacks.csv',encoding='latin-1')
df.head()

# %%
# Use at least 5 data cleaning techniques inside a file named `clean.ipynb`
# null values, columns drop, duplicated data, string manipulation, apply fn, categorize, regex, etc.

# %%
my_series = df[["year","fatal (y/n)","species"]]

# %%
print(my_series.shape)
# Out:
# (2948, 3)

# %%
# Missing values. These are the null values in the series we are analizing.

null_cols = my_series.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Series([], dtype: int64)

# %%
my_series["species"] = my_series["species"].str.lower()

# %%
my_series.head(10)
# Out:
#       year fatal (y/n)                          species
# 0   2018.0           N                      white shark
# 3   2018.0           N                        2 m shark
# 4   2018.0           N                  tiger shark, 3m
# 6   2018.0           Y                      tiger shark
# 7   2018.0           N                  lemon shark, 3'
# 8   2018.0           N                   bull shark, 6'
# 10  2018.0           N                  grey reef shark
# 13  2018.0           N                 invalid incident
# 14  2018.0           N            tawny nurse shark, 2m
# 16  2018.0           N  shark involvement not confirmed

# %%
mixed_sharks = my_series.species.str.contains("white").value_counts()

# %%
# Filtering species column looking for white sharks

whitesharks.head(10)
# Out:
# False    2287
# True      661
# Name: species, dtype: int64

# %%
white_sharks = []
other_sharks = []

for i in my_series["species"]:
    if "white" in i:
        white_sharks.append(i)
    else:
        other_sharks.append(i)
# Out:
# ['white shark', 'white shark, 3.5 m', 'white shark, 2.5 m', 'white shark', 'juvenile white shark,  2.7 to 3.2 m', 'white shark, 3.5 m', 'white shark, 4.6 m', 'white shark, 4.5 m', 'white shark, 3.5 m', 'white shark, 3.5m', 'white shark, 3 to 3.5m ', 'white shark, 3 m', "white shark, 5' to 7'", 'oceanic whitetip shark, 1.8 to 2 m', "white shark, 10'", "white shark, 11' to 13'", "white shark, 8' to 10'", "white shark, 9'", 'white shark', 'white shark, 2.5 m', 'white shark, 4 m', 'white shark', 'white shark', "white shark, female, 14'", 'white shark, 4 m', 'white shark', 'white shark, 3.5 m', "white shark, 8' to 10'", 'white shark', "white shark, 10' to 12'", 'white shark', 'white shark', 'white shark', 'white shark', 'white shark', 'white shark, 3 m', 'white shark, 3.5 m', 'white shark, 3 to 3.5m ', "white shark, 19'", "white shark, 11' to 12'", 'white shark, 2.5 m', "white shark, 11' to 12'", "white shark, 10' to 12' ", "white shark, 13'", 'white shark', 'white shark, 3.9 to 4.2 m', '
# ...

# %%
my_series_2 = my_series[my_series["fatal (y/n)"]=="Y"]

# %%
x = my_series_2.year
y = my_series_2.species

# %%
plt.scatter(x,y)
plt.bar(x,y)
plt.title("Sharks_analysis")
ax = plt.subplot()
ax.set_xticks(x)
# Out:
# <ipython-input-34-842f3dae3890>:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()
# ...

# %%
# %matplotlib inline

my_series_2 = my_series[my_series["fatal (y/n)"]=="Y"]

audis = m[m.make=="Audi"].groupby("decada").agg({"model":"count"})


white_sharks_2 = my_series_2[my_series_2.species==[i for ]

years = my_series_2 [1975 <= my_series_2["year"]<= 2018    - 
                     
set_ylabel
y = 

ferraris =  m[m.make=="Ferrari"].groupby("decada").agg({"model":"count"})


data = pd.concat([audis,ferraris], axis=1)
data.columns = ["Audi","Ferrari"]
display(data)
data.plot.bar()
